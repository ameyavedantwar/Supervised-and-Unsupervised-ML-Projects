# %%
#Name: Ameya Vedantwar
#Date: 07/10/2022
#Student Number: 2149543

# %%
x = 345
y = (2*x) + (5*5*5)
print(y)
# Out:
# 815

# %%
print("Hello World")
# Out:
# Hello World

# %%
import math
x = 345
w = 2
b = pow(5,3)
f = (w*x) + b
print(f)
# Out:
# 815

# %%
my_list = ["bike", "car", "aeroplane", "ship", "truck"]
i = len(my_list) - 1
while i>-1:
  print(my_list[i])
  i-=1
# Out:
# truck
# ship
# aeroplane
# car
# bike

# %%
def equals_100(x):
  if(x == 100):
    return True
  else:
    return False

x = int(input("Enter a number"))
print(equals_100(x))
# Out:
# Enter a number55
# False

# %%
my_dictionary = {}
data_name = "Animal counts"
label = ["cat", "dog", "fish"]
count = [2, 5, 10]

for i in range(len(label)):
  my_dictionary[label[i]] = count[i]

print(my_dictionary)
# Out:
# {'cat': 2, 'dog': 5, 'fish': 10}

# %%
print(my_dictionary.keys())
# Out:
# dict_keys(['cat', 'dog', 'fish'])

# %%
for i in my_dictionary:
    if(i == 'dog'):
        a = 'dog'
task = f"Animal name:{a} , count:{my_dictionary.get('dog')} "
print(task)
# Out:
# Animal name:dog , count:5

# %%
import numpy as np
import random
a = []
b = []
app = []
for i in range(2):
    for j in range(3):
        app.append(random.randint(10,1000))
        if(j==2):
            a.append(app)
            app = []

for i in range(3):
    for j in range(4):
        app.append(random.randint(40,1000))
        if(j==3):
            b.append(app)
            app=[]
            
print(a)
print(b)
# Out:
# [[611, 856, 46], [247, 752, 193]]
# [[369, 368, 903, 385], [427, 472, 728, 140], [237, 487, 946, 989]]

# %%
c = np.matmul(a,b)
print(c)
# Out:
# [[ 601873  651282 1218417  400569]
#  [ 457988  539831  953075  391252]]

# %%
print(c[:,0])
# Out:
# [601873 457988]

# %%
import numpy as np

df = np.load("D:/1) Swansea/1) Uni/Big data and machine learning/Labs/Iris_data.npy")

# %%
print(df.shape)
# Out:
# (150, 4)

# %%
df = np.load("D:/1) Swansea/1) Uni/Big data and machine learning/Labs/Iris_data.npy")
a = df[0]
Feature1 = df[:,0]
Feature2 = df[:,1]
#import pdb;pdb.set_trace()
import matplotlib.pyplot as plt

plt.scatter(Feature1, Feature2)
plt.show()
